# %%
import requests
from lxml import etree

# %%
url="https://baike.baidu.com/item/%E7%BE%8A%E8%97%BF%E7%9B%8A%E8%82%BE%E9%85%92"

# %%
headers={
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.9',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Cookie':'BAIDUID=1D67A84297C45FFB8928890ED428A8F2:FG=1; PSTM=1518325131; BIDUPSID=02866BFDC8A904677CE24A395DAEE3AA; BDUSS=RjMkVEV1VlUlBLYmdNclB1OWhQWC1FLTZlZm83dzVONHFnbXJqSnVwSGV2OVphQVFBQUFBJCQAAAAAAAAAAAEAAAB-inEUQ8Sn0tfTosblAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAN4yr1reMq9aMl; BK_SEARCHLOG=%7B%22key%22%3A%5B%22302%22%2C%22missile%22%5D%7D; BDORZ=B490B5EBF6F3CD402E515D22BCDA1598; H_PS_PSSID=1429_21080_22072; Hm_lvt_55b574651fcae74b0a9f1cf9c8d7c93a=1521808646,1521897598,1522037933,1522157384; pgv_pvi=4710782976; pgv_si=s550172672; locale=zh; Hm_lpvt_55b574651fcae74b0a9f1cf9c8d7c93a=1522157539',
    'Host':'baike.baidu.com',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.32 Safari/537.36',
}

# %%
r=requests.get(url,headers=headers)

# %%
r.encoding=r.apparent_encoding

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
# <html>
#
#
#
# <head>
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="referrer" content="always" />
# <meta name="description" content="羊藿益肾酒是用于治疗腰腿酸软，头晕耳鸣，气短乏力，自汗或盗汗等症状的补品。...">
# <title>羊藿益肾酒_百度百科</title>
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
# <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu.svg">
#
# <meta name="keywords" content="羊藿益肾酒 羊藿益肾酒品名 羊藿益肾酒基本信息 羊藿益肾酒包装规格 羊藿益肾酒主要成分 羊藿益肾酒功能主治 羊藿益肾酒国药准字号 羊藿益肾酒所属类别 羊藿益肾酒简要说明">
# <meta name="image" content="https://bkssl.bdimg.com/cms/static/baike.png">
# <script type="text/javascript">
#   // 配置 PD 监控。
#   window.alogObjectConfig = {
#     product: '103',
#     page: '103_1',
#     speed: {
#       sample: '0.008'
#     },
#     monkey: {
#       sample: '1',
#       hid: '1533'
#     },
#     exception: {
#       sample: '0.004'
#     },
#     feature: {
#       sample: '0.004'
#     },
#     csp: {
# ...

# %%
selector=etree.HTML(r.text)

# %%
xpath_str="//div[@class='content-wrapper']/div[@class='content']/div[@class='main-content']/div[@class='para'][15]"
xpath_str="//div[@class='main-content']/div[@class='para'][15]"


content=selector.xpath(xpath_str)

for each in content:
    print(each.text)
# Out:
# 温补肾阳。适用于肾阳虚所致之腰腿酸软，头晕耳鸣，气短乏力，自汗或盗汗，失眠健忘，大便稀薄，夜尿频多等症
