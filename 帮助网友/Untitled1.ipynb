# %%
headers={
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.9',
    'Connection':'keep-alive',
    'Cookie':'uuid=da022ca54a464e6a970c.1521769565.1.0.0; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; _lxsdk_cuid=1625088da9ec8-0c35368d7ccebd-37465265-15f900-1625088da9ec8; ci=119; rvct=119; client-id=fa7e4327-4c6d-433b-a66b-cc5a555f6690; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; _lxsdk=162519dc9ea17-0a02e56f276efa-37465265-15f900-162519dc9eb16; lat=34.373412; lng=118.352607; __mta=214285992.1521769569508.1521809995457.1521810128500.26; _lxsdk_s=16252cc3fcc-683-84e-3e4%7C%7C54',
    'Host':'www.meituan.com',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.32 Safari/537.36'
}

# %%
import http.cookiejar as HC
from bs4 import BeautifulSoup
import json
import requests
import lxml
from lxml import etree
import sys
import re
import time

# %%
url="https://www.meituan.com/cate/80274/"
html=requests.get(url,headers=headers).text
print(html)
# soup=BeautifulSoup(html,'lxml')
# div=soup.find('div',class_='category-nav-content-wrapper')
# links=[sub_link.find('span').find('span').find('a')['href'] for sub_link in div.find('ul').find_all('li')] 
# return links
# Out:
# <!DOCTYPE html><html><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="ie=edge"><title>星美国际影商城（绿地店）_星美国际影城电话地址_营业时间-徐州美团网</title><meta name="description" content="徐州美团网提供2018最新星美国际影商城（绿地店）电话，营业时间，地址，以及星美国际影商城（绿地店）人均价格，最新优惠活动，查看星美国际影商城（绿地店）团购信息，了解店铺环境/服务怎么样。"><meta name="keywords" content="星美国际影商城（绿地店），星美国际影城电话，星美国际影城地址，星美国际影城营业时间"><meta name="format-detection" content="telephone=no"><meta name="format-detection" content="address=no"><meta name="lx:category" content="group"><meta name="lx:cid" content="c_vvk6y5rx"><meta name="lx:appnm" content="mtpc"><meta name="lx:autopv" content="off"><link rel="dns-prefetch" href="//analytics.meituan.net"><link rel="dns-prefetch" href="//analytics.meituan.net"><link rel="dns-prefetch" href="//www.meituan.com"><link rel="dns-prefetch" href="//s0.meituan.net"><link rel="dns-prefetch" href="//s1.meituan.net"><link rel="dns-prefetch" href="//p0.meituan.net"><link rel="dns-prefetch" href="//p1.meituan.net"><link rel="stylesheet" ty
# ...

# %%
# pattern = re.compile(r"(?<=script>window._appState = ).*?(?=,\"extraInfos)|(?<=script>window.AppDat = ).*?(?=,\"headIco)",re.I)
# pattern = re.compile(r"(?<=script>window._appState = ).{100}",re.I)
# ript>window.AppData =
# store_detail_info=re.search(pattern,html).group(0)+"}}"
# pattern = re.compile(r"(?<=script>window.AppDat = ).*?(?=,\"headIco)",re.I)
pattern = re.compile(r"(?<=<script>window.AppData = ).*?(?=,\"headIcon\":\"http)",re.I)
store_detail_info=re.search(pattern,html).group(0)+"}}"
print(store_detail_info)
# Out:
# {"groupDealList":{"group":[{"id":33557391,"headIcon":"\u002F\u002Fp0.meituan.net\u002Fdeal\u002Ff8d6eab3a0e4c157c86a1b10401069fb42541.jpg@200w_200h_1e_1c","title":"浪漫红酒双人套餐","sold":1,"deadline":1523721599000,"price":299,"value":414,"type":0,"shortTips":"有效期：2015.12.21 至 2018.4.14\r\n不可用日期：有效期内周末、法定节假日可用\r\n美团券使用时间：10:00-24:00\r\n预约提醒：无需预约，消费高峰时可能需要等位\r\n限购限用提醒：每张美团券建议2人使用\r\n其他费用：不提供餐巾纸\r\n包间：店内无包间\r\n堂食外带：堂食外带均可，可免费打包\r\n温馨提示：2公里范围内，商家提供免费配送服务\r\n团购用户不可同时享受商家其他优惠\r\n酒水饮料等问题，请致电商家咨询，以商家反馈为准\r\n商家服务：提供免费WiFi\r\n","longTips":"仅售299元！最高价值414元的浪漫红酒双人套餐，提供免费WiFi。"},{"id":33572765,"headIcon":"\u002F\u002Fp1.meituan.net\u002Fdeal\u002Fcb98f92e062eb11d82124ec4596a2dda42040.jpg@200w_200h_1e_1c","title":"浪漫红酒双人套餐","sold":57,"deadline":1523807999000,"price":99,"value":156,"type":0,"shortTips":"有效期：2015.12.22 至 2018.4.15\r\n不可用日期：有效期内周末、法定节假日可用\r\n美团券使用时间：10:00-24:00\r\n预约提醒：无需预约，消费高峰时可能需要等位\r\n限购限用提醒：每张美团券建议1人使用\r\n其他费用：不提供餐巾纸\r\n包间：店内无包间\r\n堂食外带：堂食外带均可，可免费打包\r\n温馨提示：2公里范围内，商家提供免费配送服务\r\n团购用户不可
# ...

# %%
store_detail_info_dict=json.loads(store_detail_info)
# info=store_detail_info_dict['detailInfo']
info=store_detail_info_dict['poiInfo']
dict3={
    'name':info['name'],
    'address':info['address'],
    'phone':info['phone'],
    'open_time':info['openTime']
}
print(dict3)
# Out:
# {'name': '星美国际影商城（绿地店）', 'address': '云龙区庆丰路西绿地世纪城购物中心3层（近和平路）', 'phone': '0516-85538188', 'open_time': '周一至周日\n09:30-22:00'}
