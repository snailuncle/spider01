# %%
url='http://www.jc.net.cn/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&pno=12'

import requests
from lxml import etree

headers={
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate',
    'Accept-Language':'zh-CN,zh;q=0.9',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Cookie':'JSESSIONID=4472A910FCABCC6770A75D4BA63CA13E-n2; BIGipServernew_web=1526835392.20480.0000; _dg_check.73d33d216ded5c22.ee16=-1; _dg_playback.73d33d216ded5c22.ee16=1; jcnet=amNuZXRfN18xODYxMjI1OTAxNl8wOTNlYjA3MDAxZmNhZjJiZTg2MmQ2ZjY4ZDYzMDU1Mw%3D%3D; 4991014=4991014%2C2018-08-24; _dg_id.73d33d216ded5c22.ee16=7a232a24a3890e26%7C%7C%7C1522119550%7C%7C%7C5%7C%7C%7C1522121277%7C%7C%7C1522119719%7C%7C%7C%7C%7C%7Cd2f018f6e9ae5d40%7C%7C%7C%7C%7C%7C%7C%7C%7C1%7C%7C%7Cundefined',
    'Host':'www.jc.net.cn',
    'Referer':'http://www.jc.net.cn/jsp/front/index.jsp',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.32 Safari/537.36',
}


html=requests.get(url,headers=headers)

html_text=html.text

print(html_text)

selector=etree.HTML(html_text)



xpath_str="//table[@class='table table-bordered table-hover']/tbody[@id='tbody']/tr/td[@class='gray_FONT'][2]/text()"



content=selector.xpath(xpath_str)
print(dir(content))

for each in content:
    if len(each)>100:
        print(each.strip())

for each in content:
    print(each.strip())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <style type="text/css">
#
# </style>
# <title>黑色及有色金属-钢丝- 建材市场价格查询－建材在线</title>
#
#
# 	<meta name="keywords" content="建材，黑色及有色金属-钢丝-报价，价格查询" />
#
#
# 	<meta name="description" content="建材在线,建材市场价查询为你提供最专业的黑色及有色金属-钢丝-报价， 品牌查询" />
#
#
# <!--永远以最新的IE版本模式来显示网页 -->
# <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#
# <!--360浏览器选择内核 极速模式-->
# <meta name="renderer" content="webkit">
# <script>
#   var _dgt = _dgt || [];
#   window._dgt = _dgt;
#   (function () {
#     _dgt.push(['setSiteId', '73d33d216ded5c22']);
#     var d = document, g = d.createElement('script'),
#     s = d.getElementsByTagName('script')[0];
#     g.type = 'text/javascript'; g.async = true;
#     g.defer = true;
#     g.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'shujike.cn/dgt.js';
#     s.parentNode.insertBefore(g, s);
#
#     if('0'=='1'){
#     	_dgt.push(['trackEvent', 'search_query',['d_uid','ea_corporate_name','ea_keyword','ea_product_area','ea_customer_service','ea_search_result'], ['','','','0','','成功']]);
#     }
#   })();
# </script>
# <link href="/css/bootstrap/css/bootstrap.css" rel="stylesheet">
#
# <!--[if lte IE 6]>
# <link rel="stylesheet" type="text/css" href="/css/bootstrap/bootstrapIE6/css/bootstrap-ie6.css">
# <link rel="stylesheet" type="text/css" href="/css/bootstrap/bootstrapIE6/css/ie.css">
# <![endif]-->
#
#
#
# <link rel="stylesheet" type="text/css" media="screen" href="/css/front/pagination.css" />
#
#
# <!-- 引入qq客服样式和js start-->
# <link type="text/css" href="/css/qq/onserv.css" rel="stylesheet" />
#
#
# <link rel="stylesheet" type="text/css" href="/js/manhuatoTop/css/manhuatoTop.1.0.css" charset="utf-8"></link>
#
# <style type="text/css">
# body {
# 	font-family: '微软雅黑', '宋体', '黑体';
# 	font-size: 12px;
# 	padding-bottom: 40px;
# }
#
# /*流式间隙宽度*/
# .row-fluid [class *="span"],[class *="span"] {
# 	margin-left: 10px;
# }
#
# .container {
# 	width: 1200px;
# }
#
# .table {
# 	margin-bottom: 10px;
# }
#
# .span_lineHeight {
# 	height: 40px;
# 	line-height: 40px;
# }
#
# .accordion-inner {
# 	border-top: 0 solid #E5E5E5;
# }
#
# .accordion-group {
# 	margin-bottom: 0;
# 	border-bottom: 1px solid #E5E5E5;
# 	-webkit-border-radius: 0;
# 	-moz-border-radius: 0;
# 	border-radius: 0;
# }
#
# .row-fluid [class *='span'] {
# 	*margin-left: 0; /* ie6-7*/
# }
#
# /*导航栏css start*/
# .navbar .nav>li>a:focus,.navbar .nav>li>a:hover {
# 	color: white;
# 	background-color: #035EA7;
# 	text-decoration: none;
# 	/*background-color: transparent;*/
# }
#
# /*中间内容 */
# table>thead>tr>th {
# 	background-color: #F7F7F7;
# }
#
# table #select th,.table  #select td {
# 	border-top: 0 solid #dddddd;
# }
#
# .backgroundImage {
# 	background-image: linear-gradient(to bottom, #ffffff, #f2f2f2);
# 	background-repeat: repeat-x;
# 	background-color: #fafafa;
# }
#
# .fontSize14 {
# 	color: gray;
# 	font-weight: 700;
# 	font-size: 14px;
# }
#
# .fontSize12 {
# 	font-size: 12px;
# }
#
# .marginHeight5 {
# 	margin-top: 5px;
# 	margin-bottom: 5px;
# }
#
# .paddingHeight5 {
# 	padding-top: 5px;
# 	padding-bottom: 5px;
# }
#
# .JP {
# 	line-height: 30px;
# 	top: -5px;
# 	position: absolute;
# 	top: -5px;
# }
#
# .navbar .nav li a {
# 	color: white;
# 	text-shadow: 0 0 0 white; /*基础的文本阴影效果*/
# }
#
# #categorys .subitem em a {
# 	color: #1e50a2;
# }
#
# #sx .input-append input {
# 	border-radius: 0 0 0 0;
# 	width: 120px;
# 	color: gray;
# }
#
# .accordion-inner {
# 	padding-left: 32px;
# }
#
# #refilter .hover #b {
# 	background-position: -42px -28px;
# }
#
# #refilter #b {
# 	background: url("/images/market/index_icon_1.png");
# 	background-repeat: no-repeat;
# 	background-position: -59px -28px;
# 	height: 16px;
# 	width: 16px;
# 	overflow: hidden;
# 	margin-right: 5px;
# 	float: left;
# }
#
# .row-fluid .span10 { +
# 	margin-left: 10px; +
# 	width: 83%;
# 	width: 83.9888%;
# }
#
# A:visited,A:link {
# 	color: #1e50a2;
# 	text-decoration: none;
# }
#
# A:HOVER {
# 	color: #ff7300;
# }
#
# /*ie下兼容*/
# .navbar-inner {
# 	filter: progid:DXImageTransform.Microsoft.gradient(enabled='false', startColorstr='#0183D9', endColorstr='#0183D9', GradientType=0 )
# }
#
# .mb {
# 	border-bottom: medium none;
# 	border-top: 1px solid #e6e6e6;
# 	font-size: 0;
# 	height: 0;
# 	margin-bottom: 34px;
# 	overflow: visible;
# 	position: relative;
# 	text-align: center;
# }
#
# .mb .attr-extra {
# 	-moz-border-bottom-colors: none;
# 	-moz-border-left-colors: none;
# 	-moz-border-right-colors: none;
# 	-moz-border-top-colors: none;
# 	background: none repeat scroll 0 0 #fff;
# 	border-color: -moz-use-text-color #ddd #ddd;
# 	border-image: none;
# 	border: 1px solid #ddd;
# 	border-style: none solid solid;
# 	border-width: medium 1px 1px;
# 	cursor: pointer;
# 	display: inline-block;
# 	font-size: 12px;
# 	height: 24px;
# 	line-height: 20px;
# 	margin-top: -1px;
# 	position: relative;
# 	text-align: right;
# 	*text-align: center; /*ie6-7*/
# 	*background-color: #F7F7F7; /*ie6-7*/
# }
#
# .mb .attr-extra div {
# 	height: 24px;
# 	line-height: 24px;
# 	padding: 0 32px 0 24px;
# 	position: relative;
# }
#
# .mb .attr-extra b,.mb .close b,.mb .open b {
# 	background: url("/images/market/index_icon_1.png") no-repeat scroll 0 0 rgba(0, 0, 0, 0);
# }
#
# .mb .attr-extra b {
# 	display: block;
# 	height: 6px;
# 	overflow: hidden;
# 	position: absolute;
# 	right: 16px;
# 	top: 9px;
# 	width: 9px;
# }
#
# .mb .attr-extra b,.mb .close b {
# 	background-position: -36px -55px;
# }
#
# .mb .attr-extra.open b {
# 	background-position: -36px -48px;
# }
#
# #select .row-fluid .span1 {
# 	width: 7.5%;
# }
#
# #select .row-fluid .span2 {
# 	width: 9.8936%;
# }
#
# #select .row-fluid .span9 {
# 	width: 79.4681%;
# }
#
# #select .row-fluid .span10 {
# 	width: 82%;
# }
#
# #select .alert {
# 	float: left;
# 	width: auto;
# 	*width: 200px; /* ie6-7*/
# 	padding: 5px 20px 5px 10px;
# 	margin-bottom: 5px;
# 	margin-right: 5px;
# 	background-color: white;
# 	color: red;
# }
#
# #select .alert .close {
# 	right: -10px;
# 	top: 0;
# }
#
# #select .alert strong {
# 	color: gray;
# }
#
# #select .v-option {
# 	position: absolute;
# }
#
# #select .v-option .o-more {
# 	color: #005aa0;
# 	cursor: pointer;
# 	float: left;
# 	height: 20px;
# 	line-height: 20px;
# 	padding-right: 14px;
# 	position: relative;
# 	text-align: right;
# 	text-decoration: none;
# 	width: 31px;
# }
#
# #select .v-option .o-more b {
# 	background: url("/images/market/index_icon_2.gif") no-repeat scroll 0 0 rgba(0, 0, 0, 0);
# 	height: 5px;
# 	overflow: hidden;
# 	position: absolute;
# 	right: 5px;
# 	top: 9px;
# 	width: 7px;
# }
#
# #select .v-option .fold b {
# 	background: url("/images/market/index_icon_3.gif") no-repeat scroll 0 0 rgba(0, 0, 0, 0);
# }
#
# #select .table th,.table td {
# 	line-height: 20px;
# 	padding: 5px 5px 3px;
# 	vertical-align: middle;
# }
#
# .bottom_top {
# 	background-color: #0183DB;
# 	color: white;
# 	height: 35px;
# 	line-height: 35px;
# 	padding-top: 10px;
# }
#
# .bottom_top a:LINK,.bottom_top a:visited {
# 	color: white;
# }
#
# /*弹出login窗口背景灰化*/
# .login_overlay_bg {
# 	position: fixed;
# 	left: 0;
# 	top: 0;
# 	background-color: #8a8a8a;
# 	filter: alpha(opacity =                                                                                                             75);
# 	-moz-opacity: 0.75;
# 	opacity: 0.75;
# 	height: 100%;
# 	width: 100%;
# 	z-index: -1;
# }
# /*-选择地区-*/
# .choise_area {
# 	position: absolute;
# 	height: 260px;
# 	width: 387px;
# 	z-index: 9999;
# 	left: 50%;
# 	margin-left: -200px;
# 	padding: 1px;
# 	font-size: 12px;
# 	display: none;
# }
#
# /*收藏使用 陈正刚*/
# .c-con {
# 	height: 150px;
# 	background-color: #fff;
# 	padding: 10px 20px;
# }
#
# .city-con span {
# 	position: absolute;
# 	right: 10px;
# 	_right: 20px;
# 	top: 10px;
# }
#
# .c-con span {
# 	position: absolute;
# 	right: 10px;
# 	_right: 20px;
# 	top: 10px;
# }
#
# .clearboth {
# 	clear: both;
# }
# #tbody tr td{
# 	text-align: center;
# }
# </style>
# <!-- 请置于所有广告位代码之前 -->
# <script type="text/javascript" src="http://cbjs.baidu.com/js/m.js"></script>
# <script type="text/javascript">
# 	//if (document.domain != 'jc.net.cn' && document.domain != 'www.jc.net.cn'){
# 		 //window.location.href='http://www.jc.net.cn/';
# 	//}
# 	if(document.domain !='localhost' && document.domain !='127.0.0.1' ){
# 		if (document.domain != 'jc.net.cn' && document.domain != 'www.jc.net.cn'){
# 			 window.location.href='http://www.jc.net.cn/';
# 		}
# 	}
# 	if (top.location != self.location){
# 		top.location=self.location;
# 	}
# 	BAIDU_CLB_preloadSlots("970654","970652","970648");
# 	</script>
# </head>
#
# <body>
# 	<div class="container">
# 		<!-- logo 搜索 -->
# 		<div class="row-fluid">
#
#
# <link rel="SHORTCUT ICON" href="/images/jc16x16.ico" type="image/x-icon">
# <script type="text/javascript" src="/js/jquery/jquery-1.8.0.min.js"></script>
# <script type="text/javascript" src="/js/public/easycombobox.js"></script>
#
# <style type="text/css">
# li {
# 	list-style: none
# }
#
# h1,h2,h3,h4,h5,h6,small {
# 	font-size: 100%
# }
#
# sup,sub {
# 	font-size: 83%
# }
#
# pre,code,kbd,samp {
# 	font-family: inherit
# }
#
# q:before,q:after {
# 	content: none
# }
#
# textarea {
# 	overflow: auto;
# 	resize: none
# }
#
# label,summary {
# 	cursor: default
# }
#
# a,button {
# 	cursor: pointer
# }
#
# h1,h2,h3,h4,h5,h6,strong,b {
# 	font-weight: bold
# }
#
# del,ins,u,s,a,a:hover {
# 	text-decoration: none
# }
#
# body {
# 	background: #fff
# }
#
# a,a:hover {
# 	color: #333
# }
#
# .f-cb:after,.f-cbli li:after {
# 	display: block;
# 	clear: both;
# 	visibility: hidden;
# 	height: 0;
# 	overflow: hidden;
# 	content: ".";
# }
#
# .topfont {
# 	width: 70px;
# 	height: 38px;
# 	float: left;
# 	line-height: 37px;
# 	text-align: center;
# 	font-family: "Microsoft yahei", "微软雅黑", Arial, Helvetica, sans-serif, "宋体";
# }
#
# .hg-login,.hg-regist {
# 	font-size: 12px;
# 	color: blue;
# }
#
# .topfont a {
# 	margin-left: 8px;
# }
#
# .top-line {
# 	height: 38px;
# 	background: url(/images/nfront/dinghui.png) repeat-x;
# 	line-height: 37px;
# 	width: 100%;
# 	z-index: 9999;
# 	font: 13px/1.5 Tahoma, 'Microsoft Yahei', 'Simsun';
# 	font-family: "Microsoft yahei", "微软雅黑", Arial, Helvetica, sans-serif, "宋体";
# 	color: #757575;
# }
#
# .wellcome {
# 	height: 38px;
# 	background: url(/images/nfront/dinghui.png) repeat-x;
# 	line-height: 37px;
# 	color: #757575;
# }
#
# .king-div {
# 	margin: 0 auto;
# }
#
# .g-bd2 {
# 	margin: 0 0 10px;
# }
#
# .g-sd2 {
# 	float: right;
# }
#
# .g-mn2 {
# 	float: left;
# 	height: 39px;
# }
#
# .g-mn2c {
#
# }
#
# .g-sd2 span {
# 	margin-right: 5px;
# }
#
# .g-sd2 img {
# 	margin-right: 5px;
# }
#
# .g-bd3 {
# 	margin: 5px 0px 5px;
# }
#
# .g-sd31 {
# 	position: relative;
# 	float: left;
# 	width: 268px;
# }
#
# .hui-font {
# 	color: #aaa;
# 	font-size: 12px;
# }
#
# .g-sd32 {
# 	position: relative;
# 	float: left;
# 	width: 108px;
# }
#
# .g-sd32 p {
# 	text-align: center;
# }
#
# .g-sd31 {
# 	width: 268px;
# 	margin-right: 5px;
# }
#
# .g-mn3 {
# 	float: right;
# 	width: 100%;
# 	margin-left: -430px;
# }
#
# .g-mn3c {
# 	margin-left: 417px;
# }
#
# #logo_search {
# 	height: 76px;
# }
#
# .cities {
# 	background-color: #DDDDDD;
# 	border-right: 3px solid #ddd;
# 	border-bottom: 3px solid #ddd;
# 	padding: 5px;
# 	position: absolute;
# 	width: 430px;
# 	left: 33.5%;;;
# 	top: 112px;
# 	z-index: 9999;
# }
#
# .city-con {
# 	background-color: #fff;
# 	padding: 10px 20px;
# }
#
# .city-con dl {
# 	height: 35px;
# 	line-height: 35px;
# 	font-family: "Microsoft YaHei", arial;
# 	_font-family: arial;
# 	line-height: 18px;
# 	color: #3e3e3e;
# }
#
# .city-con dt,.city-con dd {
# 	float: left;
# }
#
# .city-con dt {
# 	padding-right: 8px;
# 	width: 72px;
# 	text-align: right;
# 	font-size: 13px;
# }
#
# .city-con dd {
# 	width: 290px;
# }
#
# .city-con dd a {
# 	margin-right: 13px;
# 	font-size: 12px;
# 	color: #996633;
# 	cursor: pointer;
# 	outline: medium none;
# 	text-decoration: none;
# }
#
# .city-con .rmen {
# 	border-bottom: 1px solid #eee;
# 	margin: 10px 0 5px 0;
# 	padding-bottom: 5px;
# }
#
# .city-con .rmen a {
# 	color: #c60000;
# 	font-size: 14px;
# 	font-weight: bold;
# }
#
# .city-con span {
# 	position: absolute;
# 	right: 10px;
# 	_right: 20px;
# 	top: 10px;
# }
#
# .clearboth {
# 	clear: both;
# }
#
# .m-nav {
# 	clear: both;
# }
#
# .m-nav,.m-nav li,.m-nav li a,.m-nav {
# 	height: 40px;
# 	line-height: 40px;
# }
#
# .m-nav,.m-nav li,.m-nav {
# 	background: url(/images/nfront/searchmenu.png) no-repeat -9999px -9999px;
# }
#
# .m-nav {
# 	position: relative;
# 	margin: 0px;
# 	text-align: center;
# 	font-size: 0;
# 	letter-spacing: -0.307em;
# 	*letter-spacing: normal;
# 	*word-spacing: -1px;
# 	color: #fff;
# 	background-repeat: repeat-x;
# 	background-position: 0 0;
# }
#
# .m-nav li,.m-nav li a {
# 	display: inline-block;
# 	*display: inline;
# 	*zoom: 1;
# }
#
# .m-nav li {
# 	padding: 0 0 0 1px;
# 	font-size: 14px;
# 	letter-spacing: normal;
# 	word-spacing: normal;
# 	background-position: 0 -150px;
# }
#
# .m-nav li.mcurrent {
# 	background: url(/images/nfront/shouys.png) repeat;
# }
#
# .m-nav li a {
# 	text-decoration: none;
# 	color: #fff;
# }
#
# .m-nav li a:hover {
# 	background: url(/images/nfront/shouys.png) repeat;
# }
#
# .m-nav li a {
# 	padding: 0 9px;
# 	font-weight: bold;
# }
#
# .m-nav .mynav-gx {
# 	background: url(/images/nfront/brk1.png) no-repeat;
# 	background-position: left;
# 	width: 120px;
# 	margin-left: 5px;
# }
#
# .mynav-gx a {
# 	padding-right: 0px !important;
# 	margin-left: 28px;
# 	font-size: 15px !important;
# }
#
# .m-nav li {
# 	list-style: none;
# 	float: none !important;
# }
#
# .icon-close,.icon-wrong {
# 	height: 14px;
# 	width: 14px;
# }
#
# .icon-close {
# 	cursor: pointer;
# }
#
# .icon-close {
# 	background: url("/images/nfront/icon.gif") no-repeat scroll 0 0 transparent;
# 	display: inline-block;
# }
#
# .p-reative {
# 	position: relative;
# }
#
# .m-nav ul li em {
# 	background: url(/images/nfront/bid_new.gif) no-repeat;
# 	width: 35px;
# 	height: 21px;
# 	display: inline-block;
# 	position: absolute;
# 	top: -12px;
# 	left: 18px;
# }
# </style>
#
# <div class="top-line">
# 	<div id="wellcome" class="wellcome king-div">
# 		<div class="g-bd2 f-cb">
# 			<div class="g-mn2">
# 				<div class="g-mn2c">
# 					<p id="loginInfoDiv">
# 						&nbsp;&nbsp;&nbsp;欢迎光临建材在线！ <font> <a id="dl" href="/jsp/front/index.jsp" class="hg-login">[登录]</a>&nbsp; <a id="mfzc" href="/jsp/front/regist_guide.jsp" class="hg-regist">[免费注册]</a> </font>
# 					</p>
# 				</div>
# 			</div>
# 			<div class="g-sd2">
# 				<li class="topfont" style="background: url(/images/nfront/i.png) no-repeat;background-position: left center;"><a href="/about/registered_problem.jsp" target="_blank">帮助中心</a>
# 				</li>
# 				<li class="topfont" style="background: url(/images/nfront/t.png) no-repeat;background-position: left center;"><a href="javascript:void(0);" onclick="gotoBbscheck()">投诉建议</a>
# 				</li>
# 				<li class="topfont" style="background: url(/images/nfront/tj.png) no-repeat;background-position: left center;"><a href="javascript:void(0);" onclick="addCookie()">添加收藏</a>
# 				</li>
# 				<li class="topfont" style="background: url(/images/nfront/lx.png) no-repeat;background-position: left center;"><a href="/about/contact_us.jsp" target="_blank">联系我们</a>
# 				</li>
# 				<li class="topfont" style="background: url(/images/nfront/jcwb.gif) no-repeat;background-position: left center;width:55px;"><a href="http://weibo.com/u/3244719213" target="_blank">微博</a>
# 				</li>
# 			</div>
# 		</div>
#
# 	</div>
# </div>
#
# <div class="king-div">
# 	<div class="g-bd3 f-cb" id="logo_search">
# 		<div class="g-sd31">
# 			<div id="logo">
# 				<div style="float: left;">
# 					<a href="/"><img src="/images/nfront/logoX1.png" alt="建材在线logo" width="255" height="76" /> </a>
# 				</div>
# 				<div style="float: right;margin:10px 10px 0 0">
# 					<img src="/images/nfront/logoline.jpg" alt="建材在线logo" width="1" style="height: 60px;"/>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="g-sd32">
# 			<div style="line-height: 20px;margin-top: 18px;">
# 				<p>
# 					<font id="aaa" color="red" style="font-family: 黑体  ;font-size: 23px;">全国站</font>
# 				</p>
# 				<p style="margin-top: 4px;">
# 					<font color="#01327b" style="font-size: 15px;font-weight: bold;cursor:pointer;" id="eee" onclick="javascript:$('.cities').toggle();">[城市切换]</font>
# 				</p>
# 				<input type="hidden" id="area_code" value="" /> <input type="hidden" id="city_code" value="" />
# 			</div>
# 		</div>
# 		<div style="float: right;position: relative;width: 150px;">
# 			<div style="line-height: 30px;height:30px; margin-top: 18px;">
# 				</div>
# 		</div>
# 		<div>
# 			<div class="g-mn3c">
# 				<div id="seach" style="background-image: url('/images/nfront/scj.png');width: 543px;height: 68px;">
# 					<div id="scj" style="cursor:pointer;;float: left;width: 57px;height: 27px;margin-top: 3.2px" onclick="check(this,0)"></div>
# 					<div id="xxj" style="cursor:pointer;float: left;width: 57px;height: 27px;margin:3.2px 0 0 1px;" onclick="check(this,1)"></div>
# 					<div id="cjj" style="cursor:pointer;float: left;width: 57px;height: 27px;margin:3.2px 0 0 1px;" onclick="check(this,2)"></div>
# 					<div id="gys" style="cursor:pointer;float: left;width: 57px;height: 27px;margin:3.2px 0 0 1px;" onclick="check(this,3)"></div>
# 					<div>
# 						<div style="float: left;" id='one-suggestion' class='tang-ui tang-suggestion' tang-param=''>
# 							<form action="#" id="form" autocomplete="off">
# 								<input id="searchHeaderText" class="tang-suggestion-input" value="" onfocus="clearKyWord()" onblur="seachBlurKey()" style="font-size:16px;width:410px;height:22px;line-height:22px; margin: 2px 2px 0 6px;border-style:none;border: 0px;" />
# 							</form>
# 						</div>
# 						<div style="float: right;">
# 							<div id="searchBtn" style="cursor:pointer;width: 58px;height: 25px;margin: 6px 8px 5px 0;" onclick="seachKeyWord();"></div>
# 						</div>
# 					</div>
# 				</div>
# 				<div style="width:225px;height:85px;margin-top:-65px;float:right">
# 					<script type="text/javascript">var mainone_wordtype=1;  var mainone_mainword="keys";var mainone_if_width=220;var mainone_color_bg="";var mainone_color_bd="";var mainonestyle=18;var mainone_color_txthover="";var mainone_color_txtbg=""; </script><script src="http://acode.b2b.cn/JS/Keyword_New.js" type="text/javascript"></script>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
#
# </div>
#
#
# <div class="cities" style="display:none;">
# 	<div style="border:1px solid #ffd8af;">
# 		<div class="city-con p-reative">
# 			<span class="icon-close" onclick="javascript:$('.cities').hide();"></span>
# 			<dl class="rmen">
# 				<dt>热门地区：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="北京" id="11">北京</a> <a href="javascript:void(0);" onclick="xxx(this);" title="广东" id="44">广东</a> <a href="javascript:void(0);" onclick="xxx(this);" title="河北" id="13">河北</a> <a href="javascript:void(0);" onclick="xxx(this);" title="湖北" id="42">湖北</a> <a href="javascript:void(0);" onclick="xxx(this);" title="四川" id="51">四川</a> <a href="javascript:void(0);" onclick="xxx(this);" title="山东" id="37">山东</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>地区：</dt>
# 				<dd>
# 					<div id="area3"></div>
# 				</dd>
# 			</dl>
# 			<div style="position:absolute;left:390px;top:70px;cursor:pointer;width:30px;font-size:12px;" onclick="xxx1();return false">确定</div>
# 			<dl>
# 				<dt>不限：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="全国" id="0">全国</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>华北：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="北京" id="11">北京</a> <a href="javascript:void(0);" onclick="xxx(this);" title="天津" id="12">天津</a> <a href="javascript:void(0);" onclick="xxx(this);" title="河北" id="13">河北</a> <a href="javascript:void(0);" onclick="xxx(this);" title="山西" id="14">山西</a> <a href="javascript:void(0);" onclick="xxx(this);" title="内蒙古" id="15">内蒙古</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>东北：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="辽宁" id="21">辽宁</a> <a href="javascript:void(0);" onclick="xxx(this);" title="吉林" id="22">吉林</a> <a href="javascript:void(0);" onclick="xxx(this);" title="黑龙江" id="23">黑龙江</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>华东：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="上海" id="31">上海</a> <a href="javascript:void(0);" onclick="xxx(this);" title="江苏" id="32">江苏</a> <a href="javascript:void(0);" onclick="xxx(this);" title="安徽" id="34">安徽</a> <a href="javascript:void(0);" onclick="xxx(this);" title="浙江" id="33">浙江</a> <a href="javascript:void(0);" onclick="xxx(this);" title="福建" id="35">福建</a> <a href="javascript:void(0);" onclick="xxx(this);" title="江西" id="36">江西</a> <a href="javascript:void(0);" onclick="xxx(this);" title="山东" id="37">山东</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>华中：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="湖北" id="42">湖北</a> <a href="javascript:void(0);" onclick="xxx(this);" title="湖南" id="43">湖南</a> <a href="javascript:void(0);" onclick="xxx(this);" title="河南" id="41">河南</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>西南：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="重庆" id="50">重庆</a> <a href="javascript:void(0);" onclick="xxx(this);" title="四川" id="51">四川</a> <a href="javascript:void(0);" onclick="xxx(this);" title="贵州" id="52">贵州</a> <a href="javascript:void(0);" onclick="xxx(this);" title="云南" id="53">云南</a> <a href="javascript:void(0);" onclick="xxx(this);" title="西藏" id="54">西藏</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>西北：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="陕西" id="61">陕西</a> <a href="javascript:void(0);" onclick="xxx(this);" title="甘肃" id="62">甘肃</a> <a href="javascript:void(0);" onclick="xxx(this);" title="青海" id="63">青海</a> <a href="javascript:void(0);" onclick="xxx(this);" title="宁夏" id="64">宁夏</a> <a href="javascript:void(0);" onclick="xxx(this);" title="新疆" id="65">新疆</a>
# 				</dd>
# 			</dl>
# 			<dl>
# 				<dt>华南：</dt>
# 				<dd>
# 					<a href="javascript:void(0);" onclick="xxx(this);" title="广东" id="44">广东</a> <a href="javascript:void(0);" onclick="xxx(this);" title="广西" id="45">广西</a> <a href="javascript:void(0);" onclick="xxx(this);" title="海南" id="46">海南</a>
# 				</dd>
# 			</dl>
# 		</div>
# 	</div>
# </div>
#
# <script type="text/javascript">
#
# var searchType = "";
#
# var seach="";
#
# function setAreaNameById(id){
# 	var url="/apps/sys/AreaAction.do?method=getAreaById";
# 	$.ajax({
# 		  type: 'POST',
# 		  url: url,
# 		  data: {areaId:id},
# 		  complete: function(data){
# 				var areaName=data.responseText;
# 				var hh = document.getElementById("aaa");
# 				hh.firstChild.nodeValue = areaName+"站";
# 		  }
# 		});
# }
#
# function getMyAreaByIp(){
#
#
# 	$.ajax( {
# 		global : false,
# 		url : "/framework/core/BaseToolAction.do?method=getHostIP&t="+new Date(),
# 		dataType : 'json',
# 		type : 'post',
# 		async : true,
# 		complete : function(msg) {
#
# 			var result=msg.responseText;
# 			if(result!="null"&&result&&result.length>2){
# 				setAreaNameById(result);
# 				document.getElementById("city_code").value=result;
# 				var area11 = result.substr(0,2);
# 				document.getElementById("area_code").value=area11;
# 				$("#area3").easycombobox("selected","1",area11,true);
# 				$("#area3").easycombobox("selected","2",result);
#
# 			}else{
# 				if(document.getElementById(result)!=null){
# 					var area = document.getElementById(result);
# 					var areahtml = area.innerHTML;
# 					var hh = document.getElementById("aaa");
# 					hh.firstChild.nodeValue = areahtml + "站";
# 					document.getElementById("area_code").value=result;
# 					$("#area3").easycombobox("selected","1",result,true);
#
# 				}
# 			}
# 		}
# 	});
# }
#
# 	function loginCheck1()
#   	{
# 	    var url = "/net/sys/FrontLoginAction.do?method=loginCheck&aaa="+new Date();
# 	    $.post(url,null,function(result){
# 			 if(!result)
# 			 {
# 				 return false;
# 			 }
#
# 			 var temp=result.split("_");
# 			var lhtm ="&nbsp;&nbsp;&nbsp;欢迎光临建材在线！<font id='loginInfoDivs'>您 好: "+(temp[0]=='null'?'':(temp[0].length>15?temp[0].substring(0,14)+'...':temp[0]))+"<span class='ogray_FONT mar_left' > "+(temp[1]=='null'?'':(temp[1].length>15?temp[1].substring(0,14)+'...':temp[1]))+"</span>&nbsp;&nbsp;<a style='color:#0088cc;background:url(/images/nfront/ren.png) no-repeat;' href='/net/sys/FrontLoginAction.do?method=index'><strong style='margin-left:14px;'>我的账户</strong></a>&nbsp;<a  style='color:#0088cc' id='exitBtn' href='javascript:startExit();'>退&nbsp;出</a></font>";
# 			 $("#loginInfoDiv").css("display","block");
# 			 $("#loginInfoDiv").html(lhtm);
# 	    });
#
#   	}
#
# function check(my,type){
# 		if(searchType!=null){
# 			seach[searchType].style.backgroundImage="";
# 			seachKey();
# 		}
# 		if(type==0){
# 			my.style.backgroundImage="url('/images/nfront/scj1.png')";
# 			searchType=type;
# 			seachKey();
# 		}
# 		else if(type==1){
# 			my.style.backgroundImage="url('/images/nfront/scj2.png')";
# 			searchType=type;
# 			seachKey();
# 			var targetUrl='/page/price/infor/';
# 			 var curl = "/net/sys/FrontLoginAction.do?method=loginCheck&aaa="+new Date();
# 	   		 $.post(curl,null,function(result){
# 				 if(!result)
# 				 {
# 					var url='/net/sys/FrontLoginAction.do?method=recordOldUrl';
# 					$.ajax({
# 						url:url,
# 						type:'post',
# 						data:'target='+targetUrl,
# 						complete: function(){
# 								startLogin();
# 						}
# 					});
# 				 }
# 			});
#
# 		}
# 		else if(type==2){
# 			my.style.backgroundImage="url('/images/nfront/scj3.png')";
# 			searchType=type;
# 			seachKey();
# 		}
# 		else if(type==3){
# 			my.style.backgroundImage="url('/images/nfront/scj4.png')";
# 			searchType=type;
# 			seachKey();
# 		}
# 	}
#
# 	var defstr=' 例：搜索"圆钢φ10内",输入:"圆钢 10"';
# 	function seachKey(){
#
# 		var oldval = $("#searchHeaderText").val();
# 		var nowval = $.trim(oldval);
#
# 		if(searchType==0||searchType==2){
# 			if(nowval == ""){
# 				$("#searchHeaderText").val(defstr);
# 				$("#searchHeaderText").css("line-height","25px");
# 				$("#searchHeaderText").css("color","#757575");
# 			}
#
# 		}else{
#
# 			if(nowval == "" || oldval == defstr){
# 				$("#searchHeaderText").val("");
# 				$("#searchHeaderText").css("color","#000");
# 			}
# 		}
# 	}
#
# 	function seachBlurKey(){
# 		if(searchType==0||searchType==2){
# 			var nowval = $.trim($("#searchHeaderText").val());
# 			if(nowval==""){
# 				$("#searchHeaderText").val(defstr);
# 				$("#searchHeaderText").css("line-height","25px");
# 				$("#searchHeaderText").css("color","#757575");
# 			}
# 		}
# 	}
#
# 	function clearKyWord(){
# 		var keywords=$("#searchHeaderText").val();
# 		if(keywords==defstr){
# 			$("#searchHeaderText").val("");
# 		}
# 		$("#searchHeaderText").css("color","#000");
# 	}
# 	function addCookie()
# 	{
# 		var curWwwPath=window.document.location.href;
# 	    if (document.all)
# 	       {
# 	         window.external.addFavorite(curWwwPath,'建材在线网站');
# 	       }
# 	      else if (window.sidebar)
# 	      {
# 	          window.sidebar.addPanel('建材在线网站', curWwwPath, "");
# 	    }
# 	}
# 	function startLogin(){
#   		location.href="/jsp/front/index.jsp?parm="+Math.random();
#   	}
# 	function gotoBbscheck(){
# 		var targetUrl1='/jsp/front/bbs/leaveMsg.jsp';
# 		var curl = "/net/sys/FrontLoginAction.do?method=loginCheck&aaa="+new Date();
# 		 $.post(curl,null,function(result){
# 			if(!result)
# 			{
# 				var url='/net/sys/FrontLoginAction.do?method=recordOldUrl';
# 				$.ajax({
# 					url:url,
# 					type:'post',
# 					data:'target='+targetUrl1,
# 					complete: function(){
# 								startLogin();
# 					}
# 				});
#
# 			}else{
# 				location.href=targetUrl1;
# 			}
# 		});
# 	}
# $(document).ready(function(){
# 	$("#area3").easycombobox({
# 			url:getUrl,
# 			valueField:'area_id',
# 			textField:'short_name'
# 		 });
#  	getMyAreaByIp();
#    	loginCheck1();
# 	seach=$("#seach>div");
#
# 		if(searchType!=""){
# 			var typeint = parseInt(searchType) +1;
# 			seach[searchType].style.backgroundImage="url('/images/nfront/scj"+typeint+".png')";
# 			seachKey();
# 		}else{
# 			searchType = 0;
# 			$("#scj")[0].style.backgroundImage="url('/images/nfront/scj1.png')";
# 			seachKey();
# 		}
# 		$("#searchHeaderText").keydown(function(e){
# 			var curkey = e.which;
# 			if(curkey == 13){
# 				seachKeyWord();
# 			return false;
# 			}
# 		});
# });
#
# function getUrl(value){
# 	if(value==-1){
# 		return "/apps/sys/AreaAction.do?method=selectParentArea";
# 	}else if(value!=0){
# 		return "/apps/sys/AreaAction.do?method=selectChlidArea&area_id="+value;
# 	}
# }
# function xxx(whichele){
# 	var hh = document.getElementById("aaa");
# 	var text = whichele.getAttribute("title");
#
# 	var changehh = hh.firstChild.nodeValue;
# 	var ss = whichele.getAttribute("id");
# 	$("#area3").easycombobox("selected","1",ss,true);
# 	hh.firstChild.nodeValue = text+"站";
#
# 	$('.cities').hide();
# }
# function xxx1(whichele){
# 	var hh = document.getElementById("aaa");
# 	var provinces = $("#area3").easycombobox("getValue",1)  ;
# 	var city = $("#area3").easycombobox("getValue",2);
# 	var provinces_name = $("#area3").easycombobox("getText",1) ;
# 	var city_name = $("#area3").easycombobox("getText",2) ;
# 	if(provinces == 0){
# 			hh.firstChild.nodeValue = "全国站";
# 		}else if(provinces != null && city == 0){
# 			hh.firstChild.nodeValue = provinces_name+"站";
# 		}else if (provinces != null && city != null){
# 			hh.firstChild.nodeValue = city_name+"站";
# 	}
#
# 	$('.cities').hide();
# }
# function gotoLoginxxj(){
# 	var targetUrl='/xxj/';
# 	var curl = "/net/sys/FrontLoginAction.do?method=loginCheck&aaa="+new Date();
# 	 $.post(curl,null,function(result){
# 		if(!result)
# 		{
# 			var url='/net/sys/FrontLoginAction.do?method=recordOldUrl';
# 			$.ajax({
# 					url:url,
# 					type:'post',
# 					data:'target='+targetUrl,
# 					complete: function(){
# 							startLogin();
# 					}
# 				});
# 		}else{
# 			location.href=targetUrl;
# 		}
# 	});
# }
#
#
# function seachKeyWord(){
#
# 	var hh = document.getElementById("aaa");
# 		var provinces = $("#area3").easycombobox("getValue",1);
#
# 	var city = $("#area3").easycombobox("getValue",2);
# 	var provinces_name = $("#area3").easycombobox("getText",1) ;
# 	var city_name = $("#area3").easycombobox("getText",2) ;
# 	var area;
# 	var area_name="";
# 	if(provinces == 0){
# 		area = 0;
# 		hh.firstChild.nodeValue = "全国站";
# 	}else if(provinces != null && (city == 0||city == undefined)){
# 		area = provinces;
# 		area_name = provinces_name;
# 		hh.firstChild.nodeValue = provinces_name+"站";
# 	}else if (provinces != null && city != null){
# 		area = city;
# 		area_name = city_name;
# 		hh.firstChild.nodeValue = city_name+"站";
# 	}
#
#  	updateUserArea(area);
# 	var searchHeaderText = document.getElementById("searchHeaderText").value;
# 		if(searchHeaderText==defstr){
# 			searchHeaderText="";
# 		}
# 			searchHeaderText = encodeURIComponent(encodeURIComponent(searchHeaderText));
# 		if(area)
# 			var area_name11 = encodeURIComponent(encodeURIComponent(area_name));
# 		var searchArea="";
# 		var searchMarket="";
# 		var searchDealPrice="";
# 		var searchInfor="";
# 		if(area&&area!=0){
# 			searchArea+="&area="+area;
# 			searchMarket+="&area="+area;
# 			searchDealPrice+="&a="+area;
# 			searchInfor+="&p_area_code="+area;
#    			}
#
# 		if(area_name&&area!=0){
# 			searchArea+="&area_name="+area_name11+"&area_leaf=N";
# 			searchMarket+="&area_name="+area_name11+"&area_leaf=N";
# 		}
#
#    		if(searchType==''||searchType==0)
#    		{
#
# 		   		 var sk = document.getElementById("searchHeaderText").value;
# 		   		  sk=sk.replace("#","");
# 		   		 sk=encodeURI(sk,"utf-8");
# 		   		 var cstr="";
# 		   		 if(area){
# 			   		 var aname=area_name;
# 			   		 if(aname){
# 			   		 	aname=encodeURI(aname,"utf-8");
# 			   		 	cstr=aname;
# 			   		 }
# 		   		 }
# 		   		 var av1=$("#area3").easycombobox("getValue",1);
# 		   		 var av2=$("#area3").easycombobox("getValue",2);
# 		   		  if(av2==null){
# 		   		  	av2="";
# 		   		  }
#
# 	   		    location.href="/market/search.html\?keys="+sk+"&area_name="+cstr+"&province="+av1+"&city="+av2+"&t1=&t2=&st=&jgjs=&pno=1";
#
#    		}
#    		if(searchType==1)
#    		{
#    			var sk = document.getElementById("searchHeaderText").value;
# 	   		 sk=encodeURI(sk,"utf-8");
# 	   		var cstr="";
# 	   		var areastring = "";
# 	   		 if(area){
# 		   		 var aname=area_name;
# 		   		 if(aname){
# 		   		 	aname=encodeURI(aname,"utf-8");
# 		   		 	cstr="&area_name="+aname;
# 		   		 }
# 		   		// areastring ="&citys="+area;
# 	   		 }
#
# 	   		 var av1=$("#area3").easycombobox("getValue",1);
# 	   		 var av2=$("#area3").easycombobox("getValue",2);
# 	   		 if(av2&&av2!="0"){
# 	   			areastring ="&city="+av2;
# 	   		 }else if(av1&&av1!="0"){
# 	   			areastring ="&provinces="+av1;
# 	   		 }
#
#   		 location.href="/price.do?method=infor_price&searchType=1&searchkeyword="+sk+cstr+areastring;
#   		}
#    		if(searchType==2)
#    		{
#    		 location.href="/net/eprice/deal/DealPriceAction.do?searchType=2&method=gotoTradtPricePage&kw="+searchHeaderText+searchDealPrice;
#    		}
#    		if(searchType==3)
#    		{
# 	   		 var sk3 = document.getElementById("searchHeaderText").value;
# 	   		 var cstr3="";
# 	   		 var aname="";
# 	   		 if(area){
# 		   		 aname=area_name;
# 		   		 if(aname){
#
# 		   		 }
# 	   		 }
#
# 	   	     var av=$("#area3").easycombobox("getValue");
# 	   		 var searchHeaderText2 = document.getElementById("searchHeaderText").value;
# 	   		 //searchHeaderText2=encodeURI(searchHeaderText2,"utf-8");
# 	   		 var searchArea2="";
# 	   		 url="/company\/search\?keys="+sk3+"&area="+aname;
# 	   		 url=encodeURI(encodeURI(url));
#    			 location.href=url;
#
# }
# }
#
# </script>
#
#
#
# <script type="text/javascript" src="/js/magic/magic.js"></script>
# <link rel="stylesheet" href="/js/magic/resources/default/common/common.css" type="text/css"></link>
# <link rel="stylesheet" href="/js/magic/resources/default/magic.control.Suggestion/magic.control.Suggestion.css" type="text/css"></link>
# <style type='text/css'>
# .tang-suggestion-popup {
# 	box-shadow: 0px 2px 2px #e1e1e1;
# 	-webkit-box-shadow: 0px 2px 2px #e1e1e1;
# 	-moz-box-shadow: 0px 2px 2px #e1e1e1;
# }
# </style>
#
# <script type="text/javascript">
# var options = {
#     getData: function(key){
#         var me = this;
#         var key1=sk=encodeURI(key,"utf-8");
#         $.ajax("/mprice.do?method=getKeySuggestion", {
#             'method': 'POST',
#             'timeout': 2000,
#             'dataType': 'json',
#             data: {
#                 "q": key1
#             },
#             'success': function(data, status, xhr){
#                 me.receiveData(key, data);
#             }
#         });
#     }
#
# };
#
# var instance = magic.setup.suggestion('searchHeaderText',options);
#
# </script>
#
#
# 		</div>
#
# 		<!-- 导航栏 -->
# 		<div class="row-fluid">
#
# <style>
# #categorys .item .i-mc {
# 	width: 750px;
# }
#
# #categorys .subitem {
# 	width: 100%;
# }
#
# #categorys .subitem dt {
# 	float: left;
# 	line-height: 22px;
# 	text-align: right;
# 	width: 15%;
# }
#
# #categorys .subitem dd {
# 	float: left;
# 	width: 82%;
# }
#
# .navbar #cloudInquiryPrice em {
# 	background: url("http://www.jc.net.cn/images/nfront/bid_new.gif") no-repeat;
# 	width: 35px;
# 	height: 21px;
# 	display: inline-block;
# 	position: absolute;
# 	top: -12px;
# 	left: 18px;
# }
# </style>
# <div class="navbar" style="margin-bottom: 10px;font-size: 14px;">
# 	<div class="navbar-inner" style="padding-left: 0;background-image: url('http://www.jc.net.cn/images/nfront/searchmenu.png'); color: black; ">
# 		<ul class="nav">
# 			<li style="width: 210px;background-image: url('http://www.jc.net.cn/images/nfront/shouys.png');" id="categorys"><a href="#" class="mt" style="color: white;display: block;"> 全部分类<b> </b> </a>
#
# 				<div clstag="homepage|keycount|home2012|06b" class="mc" id="_JD_ALLSORT" load="2" style="display: none;">
# 					<div class="item fore2">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">通用材料 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type1"></div>
# 						</div>
# 					</div>
# 					<div class="item fore3">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);"> 装饰材料 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type2"></div>
# 						</div>
# 					</div>
# 					<div class="item fore4">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">给排水材料及设备 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type3"></div>
# 						</div>
# 					</div>
# 					<div class="item fore5">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);"> 暖通材料及设备 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type4"></div>
# 						</div>
# 					</div>
# 					<div class="item fore6">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);"> 消防材料及设备 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type5"></div>
# 						</div>
# 					</div>
# 					<div class="item fore7">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">电气材料及设备 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type6"></div>
# 						</div>
# 					</div>
# 					<div class="item fore8">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);"> 其他材料及设备</a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type7"></div>
# 						</div>
# 					</div>
# 					<div class="item fore9">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">市政材料 </a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type8"></div>
# 						</div>
# 					</div>
# 					<div class="item fore10">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">仿古材料</a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type9"></div>
# 						</div>
# 					</div>
# 					<div class="item fore11">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">园林绿化</a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type10"></div>
# 						</div>
# 					</div>
# 					<div class="item fore12" style="padding-bottom: 9px;">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);">工程机械台班</a>
# 							</h3> <s> </s> </span>
# 						<div class="i-mc">
# 							<div class="subitem" id="type11"></div>
# 						</div>
# 					</div>
#
# 					<div class="item fore12" style="padding-bottom: 9px; display: none;">
# 						<span>
# 							<h3>
# 								<a href="javascript:void(0);"> 全部商品分类 </a>
# 							</h3> </span>
#
# 					</div>
# 				</div></li>
# 			<li><a href="/" style="list-style-type:none; list-style-position:inside;">首页</a>
# 			</li>
# 			<li class="active" style="list-style-type:none; list-style-position:inside;"><a href="/market/">市场价</a>
# 			</li>
# 			<li><a href="/xxj/" onclick="gotoLoginxxj();return false;" style="list-style-type:none; list-style-position:inside;">信息价</a>
# 			</li>
# 			<li><a href="/eprice/">成交价</a>
# 			</li>
# 			<li><a href="/price/rg/">人工价</a>
# 			</li>
# 			<li><a href="/xunjia/">人工询价</a>
# 			</li>
# 			<li><a href="/company/listall.html">供应商</a>
# 			</li>
# 			<li style="position:relative;" id="cloudInquiryPrice"><a href="/cloud/" target="_blank">云询价</a><em></em></li>
# 			<li><a href="/page/price/tool/tool_computer_gangban.jsp">常用工具</a>
# 			</li>
# 			<li><a href="/net/eprice/material/MaterialAction.do?method=gotoMaterialList">常用材料走势</a>
# 			</li>
# 			<li><a href="/page/biz/info/">资讯</a>
# 			</li>
# 			<li id="gx"><img src="http://www.jc.net.cn/images/nfront/brk1.png" style="height: 40px;">
# 			</li>
# 			<li><a href="/page/biz/">供需平台</a>
# 			</li>
#
# 		</ul>
# 	</div>
# </div>
# <script>
# 	function gotoLoginxxj() {
# 		var targetUrl = '/xxj/';
# 		var curl = "/net/sys/FrontLoginAction.do?method=loginCheck&aaa=" + new Date();
# 		$.post(curl, null, function(result) {
# 			if (!result) {
# 				var url = '/net/sys/FrontLoginAction.do?method=recordOldUrl';
# 				$.ajax({
# 					url : url,
# 					type : 'post',
# 					data : 'target=' + targetUrl,
# 					complete : function() {
# 						startLogin();
# 					}
# 				});
# 			} else {
# 				location.href = targetUrl;
# 			}
# 		});
# 	}
# </script>
# 		</div>
# 		<!-- 全部导航 -->
#
#
# 		<!-- 网页中间（分类，内容） -->
# 		<div class="row-fluid">
#
# 			<!-- 分类 -->
# 			<div class="span2">
#
#
#
# 						<div class="accordion" id="refilter">
#
# 								<div class='accordion-group'>
# 									<div class='accordion-heading' style='background-color: #F7F7F7;font-weight: 800;'>
# 										<a class='accordion-toggle' title="黑色及有色金属" data-toggle='collapse' href='javascript:void(0);#collapseOne0'>
# 											<div id='b'></div>黑色及有色金属</a>
# 									</div>
# 									<div id='collapseOne0' class='accordion-body collapse'>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E6%9D%BF&st=&jgjs=&goodsattr=&pno=1' title='钢板' style="">钢板</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E7%AD%8B&st=&jgjs=&goodsattr=&pno=1' title='钢筋' style="">钢筋</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E5%9C%86%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='圆钢' style="">圆钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E5%85%B6%E5%AE%83%E9%87%91%E5%B1%9E%E6%9D%90%E6%96%99&st=&jgjs=&goodsattr=&pno=1' title='其它金属材料' style="">其它金属材料</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E8%A7%92%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='角钢' style="">角钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=H%E5%9E%8B%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='H型钢' style="">H型钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E6%A7%BD%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='槽钢' style="">槽钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E5%B7%A5%E5%AD%97%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='工字钢' style="">工字钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9C%E6%A3%92%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铜棒材' style="">铜棒材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9D%E6%9D%BF%EF%BC%88%E5%B8%A6%EF%BC%89%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铝板（带）材' style="">铝板（带）材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E6%96%B9%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='方钢' style="">方钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&goodsattr=&pno=1' title='钢丝' style="color: red;font-weight: 800;">钢丝</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E6%89%81%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='扁钢' style="">扁钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E5%85%B6%E5%AE%83%E5%9E%8B%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='其它型钢' style="">其它型钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9D%E5%90%88%E9%87%91%E5%BB%BA%E7%AD%91%E5%9E%8B%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铝合金建筑型材' style="">铝合金建筑型材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E5%B8%A6&st=&jgjs=&goodsattr=&pno=1' title='钢带' style="">钢带</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9C%E6%9D%BF&st=&jgjs=&goodsattr=&pno=1' title='铜板' style="">铜板</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D%E7%BB%B3&st=&jgjs=&goodsattr=&pno=1' title='钢丝绳' style="">钢丝绳</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9D%E5%9E%8B%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铝型材' style="">铝型材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%87%91%E5%B1%9E%E5%8E%9F%E6%9D%90%E6%96%99&st=&jgjs=&goodsattr=&pno=1' title='金属原材料' style="">金属原材料</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%94%8C%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='锌材' style="">锌材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9D%E6%A3%92%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铝棒材' style="">铝棒材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E7%BB%9E%E7%BA%BF%E3%80%81%E9%92%A2%E4%B8%9D%E6%9D%9F&st=&jgjs=&goodsattr=&pno=1' title='钢绞线、钢丝束' style="">钢绞线、钢丝束</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9D%E7%BA%BF%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铝线材' style="">铝线材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%9C%E7%BA%BF%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铜线材' style="">铜线材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%95%8D%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='镍材' style="">镍材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=Z%E5%9E%8B%E9%92%A2&st=&jgjs=&goodsattr=&pno=1' title='Z型钢' style="">Z型钢</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# 												<a href='/market/search.html?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%93%85%E6%9D%90&st=&jgjs=&goodsattr=&pno=1' title='铅材' style="">铅材</a>
# 											</div>
#
# 											<div class='accordion-inner'>
#
# ...
# 							</div>
# 							<div style="margin-top:40px;margin-left:110px;" id="confirmbutton">
# 								<input type="button" value="收藏" class="btn" id="sub1" style="margin-top:-8px;width:40px;height:25px;padding:2px;font-size:12px;font-family:微软雅黑" onclick="subm('1');" /> &nbsp;&nbsp;&nbsp;&nbsp; <input type="button" value="取消" class="btn" style="margin-left:10px;margin-top:-8px;width:40px;height:25px;padding:2px;font-size:12px;font-family:微软雅黑" onclick="closeLogGreyBox1()" />
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
#
# 	</div>
#
#
# 	<script type="text/javascript">
# 	function showLogGreyBox(){
# 		 recordUrlToSession("/net/sys/FrontLoginAction.do?method=recordOldUrl"); //记录URL
# 		 startLogin();//登录页面
# 	}
#
#
# 	function skipPage(){
# 		var tpage = 50;
# 		var skipPage = document.getElementById("jumpto").value;
#
# 		var flag = /^[-\+]?\d+$/.test(skipPage);
# 		if(flag){
# 			//跳转页数 大于总页数，则跳转至最后一页
# 			skipPage = (skipPage-tpage)>0 ? tpage : skipPage;
# 			//跳转页数小于1，则跳转至第一页
# 			skipPage = skipPage < 1 ? 1 : skipPage;
# 			//gotoPage(skipPage);
# 			var url="/market/search.html\?keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&pno="+skipPage;
# 			window.location.href = url;
# 		} else {
# 			alert("请输入整数");
# 		}
# 	}
#
#
#
# 		//清除条件
# 		function clearCondition(t){
# 			var url="/market/search.html\?";
# 			if(t=="area"){
# 				var provinces='0';
# 				var city='0';
# 				if(provinces&&city){
# 					//url=getCurCondition("city");
# 					if(provinces && city!=0){
# 						url=url+"keys=&area_name=&province=0&city=&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&pno=1";
# 					}else{
# 						url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&pno=1";
# 					}
#
# 				}else{
# 					url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=&pno=1";
# 					//url=getCurCondition("provinces,city");
# 				}
# 				window.location.href = url;
# 			}else if(t=="type"){
#
# 				var t1='黑色及有色金属';
# 				var t2='钢丝';
# 				if(t1&&t2){
# 					//url=getCurCondition("t2");
# 					url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=&st=&jgjs=&pno=1";
# 				}else{
# 					url=url+"keys=&area_name=&province=0&city=&t1=&t2=&st=&jgjs=&pno=1";
# 					//url=getCurCondition("t1,t2");
# 				}
# 				window.location.href = url;
# 			}else if(t=="st"){//规格和关键字
# 				var st='';
# 				var searchkeyword='';
# 				var jgjss="";
# 			  	if(''){
# 			  		jgjss+="&product_name_f=";
# 			  	}
# 				if(''){
# 					jgjss+="&materialName_f=";
# 				}
#
# 				if(''){
# 					jgjss+="&material_Quality_f=";
# 				}
#
# 				if(''){
# 					jgjss+="&material_Brand_f=";
# 				}
#
# 				if(st&&searchkeyword){
# 					  url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs="+jgjss+"&pno=1";
#
# 				}else{
# 					 url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs="+jgjss+"&goodsattr=&pno=1";
# 				}
# 				window.location.href = url;
#
# 			}else if(t=="materialProductName"){//材料名称
# 				url=url+getjgjsStr("product_name_f");
# 				window.location.href = url;
# 			}else if(t=="comp"){//厂商
# 				url=url+getjgjsStr("comp,materialName_f");
# 				window.location.href = url;
# 			}
# 			if(t=="material_Quality_f"){  //材质
# 				url=url+getjgjsStr("material_Quality_f");
# 				window.location.href = url;
# 			}else if(t=="material_Brand_f"){  //品牌
# 				url=url+getjgjsStr("material_Brand_f");
# 				window.location.href = url;
# 			}else{
# 				var arrays='';
# 				arrays=arrays.split(",");
# 				var ga="";
# 				for(var i=0;i<arrays.length;i++){
# 					if(arrays[i]!=t){
# 						ga+=arrays[i];
# 						if(i<arrays.length-1){
# 							ga+=",";
# 						}
# 					}
# 			    }
# 				ga=encodeURI(ga,"utf-8");
# 				url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs="+jgjss+"&goodsattr="+ga+"&pno=1";
# 				window.location.href = url;
# 			}
# 		};
#
#
#
# 		//点击 筛选
# 		function furitsearch(v){
# 			var jgjs="";
# 			var st='';
# 			var url="/market/search.html\?";
# 			jgjs=filterTerm(jgjs);
# 			st=filterTerm(st);
#
# 			var order="";
# 			if(v!="true"){
# 				var vn=$("#"+v).attr("name");
# 				if(v=="xgd"){
# 					jgjs+="&order="+vn;
#
# 				}else if(v=="jg" || v=="sj"){
# 					jgjs+="&order="+vn;
#
# 				}
#
# 			}
#
# 			//分组
# 			var gr='';
# 			if(gr){
# 				jgjs+="&group="+gr;
# 			}
#
# 			url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st="+st+"&jgjs="+jgjs+"&goodsattr=&pno=1";
# 			window.location.href = url;
# 		}
#
#
# 		function filterTerm(jgjs){
# 			//结果中检索
# 			var product_name_f=$("#product_name").val()=='请输入 材料名称'?'':encodeURI($("#product_name").val(),"utf-8");//材料名称
# 			var materialName_f=$("#materialName").val()=='请输入 厂商名称'?'':encodeURI($("#materialName").val(),"utf-8");//厂商
# 			var material_Unit_f=$("#material_Unit").val()=='请输入 规格型号'?'':encodeURI($("#material_Unit").val(),"utf-8"); //规格型号
# 			var material_Quality_f=$("#material_Quality").val()=='请输入 材质'?'':encodeURI($("#material_Quality").val(),"utf-8"); //材质
# 			var material_Brand_f=$("#material_Brand").val()=='请输入 品牌'?'':encodeURI($("#material_Brand").val(),"utf-8");//品牌
# 			if(product_name_f){ //材料名称
# 				jgjs+="&product_name_f="+product_name_f;
# 			}
# 			if(materialName_f){//厂商
# 				jgjs+="&materialName_f="+materialName_f;
# 			}
# 			if(material_Unit_f){//规格型号
# 				jgjs+="&material_Unit_f="+material_Unit_f;
# 			}
# 			if(material_Quality_f){//材质
# 				jgjs+="&material_Quality_f="+material_Quality_f;
# 			}
# 			if(material_Brand_f){//品牌
# 				jgjs+="&material_Brand_f="+material_Brand_f;
# 			}
# 			return jgjs;
# 		}
#
# 		function furitsearch_group(v){
# 			var jgjs="";
# 			var st='';
# 			var url="/market/search.html\?";
# 			jgjs=filterTerm(jgjs);
# 			st=filterTerm(st);
#
# 			//排序
# 			var order='';
# 			if(order){
# 				jgjs+="&order="+order;
# 			}
#
# 			//分组
# 			var group="";
# 			if(v){
# 				var hb=$("#"+v).attr("name");
# 				if(v=="hb"){
# 					jgjs+="&group="+hb;
# 				}
# 			}
#
# 			//平均价
# 			var price="";
# 			if(v.indexOf("bigdata")!=-1){
# 				var price=$("#"+v).text();
# 				price=price.split("元");
# 				if(price[0]){
# 					jgjs+="&group=hb&price="+price[0]+"_"+v;
# 				}
#
# 			}
#
# 			url=url+"keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st="+st+"&jgjs="+jgjs+"&pno=1";
# 			window.location.href = url;
# 		}
#
#
# 		function getjgjsStr(butkey){
# 			var urlstr="";
# 			var url="keys=&area_name=&province=0&city=0&t1=%E9%BB%91%E8%89%B2%E5%8F%8A%E6%9C%89%E8%89%B2%E9%87%91%E5%B1%9E&t2=%E9%92%A2%E4%B8%9D&st=&jgjs=";
# 			//结果中检索
# 			if(''){ //材料名称
#
# 				if(butkey.indexOf("product_name_f")==-1){
# 					var v='';
# 					urlstr+="&product_name_f="+v;
# 				}
# 			}
# 			if(''){//厂商
# 				if(butkey.indexOf("materialName_f")==-1){
# 					var v='';
# 					urlstr+="&materialName_f="+v;
# 				}
#
# 			}
# 			if(''){  //推荐厂商
# 				if(butkey.indexOf("comp")==-1){
# 					var v='';
# 					urlstr+="&comp="+v;
# 				}
# 			}
# 			if(''){//规格型号
# 				if(butkey.indexOf("material_Unit_f")==-1){
# 					var v='';
# 					urlstr+="&material_Unit_f="+v;
# 				}
# 			}
# 			if(''){//材质
# 				if(butkey.indexOf("material_Quality_f")==-1){
# 					var v='';
# 					urlstr+="&material_Quality_f="+v;
# 				}
#
# 			}
# 			if(''){//品牌
# 				if(butkey.indexOf("material_Brand_f")==-1){
# 					var v='';
# 					urlstr+="&material_Brand_f="+v;
# 				}
#
# 			}
# 			urlstr=url+urlstr+"&pno=1";
# 			return urlstr;
# 		}
#
#
#
# 		function clearAll(){
# 				var url="/market/search.html\?keys=&area_name=&province=0&city=&t1=&t2=&st=&jgjs=&pno=1";
# 				window.location.href=url;
# 		}
#
# 	</script>
#
# 	<script type="text/javascript">
#
# function createclass(){
#
# 	document.getElementById("newClass").disabled="disabled";
# 	$('#createclass').show();
# 	$("#class_name").val("");
#  	$("#confirmbutton").hide();
# }
# function cancelclass(){
# 	$('#createclass').hide();
# 	$("#confirmbutton").show();
# 	document.getElementById("newClass").disabled="";
# }
# function cancelmoveclass(){
# 	$('.moveclass').hide();
# }
# function subm(tag){
#
# 	document.getElementById("sub1").disabled="disabled";
# 	collectMaterial(tag);
# }
#
#
# function collectMaterial(tag){
# 	var inquerycode= inqueryobj;
# 	var select_class_id = $("#class_id").val();
#
# 	var url = '/net/cloudinquiry/MyCollection.do?method=saveCollection&inquerycode='+inquerycode+'&tag='+tag+'&select_class_id='+select_class_id;
# 	$.ajax({
# 	   type: "POST",
# 	   url: url,
# 	   dataType: 'text',
# 	   success: function(data){
# 	     if(data=="true"){
# 	    	 closeLogGreyBox1();
# 	    	 alert("收藏成功");
# 	     }else{
# 	    	 alert(data);
# 	     }
# 	   }
# 	})
#
# }
#
# function addclass(tag){
# 	var classname=$("#class_name").val();
# 	if(classname!=null&&classname!=""){
# 		classname = encodeURI(classname,"utf-8");
# 		var url = '/net/cloudinquiry/MyCollection.do?method=addClass&classname='+classname+'&tag='+tag;
# 		$.ajax({
# 		   type: "POST",
# 		   url: url,
# 		   dataType: 'text',
# 		   success: function(data){
#
# 		     if(data!=null&&data!=""){
#
# 		    	 data = eval("("+data+")");
#
# 		    	 if(data.success){
# 		    		 //var html = '<tr><td><div class="folder"></div></td><td><div style="width: 150px;" class="ov_hidden">'+data.name+'</div></td><td><div style="color:red;cursor:pointer;width:25px;" onclick="deleteclass('+data.id+');">删除</div></td></tr>';
# 		    		 var html = "<option value="+data.id+" selected='selected'>"+data.name+"</option>";
# 		    		 $("#class_id").append(html);
# 		    		 $("#createclass").hide();
# 		    		 $("#confirmbutton").show();
#
# 		    	 }else{
# 		    		 alert("添加失败");
# 		    	 }
# 		     }else{
# 		    	 alert("分类已存在!");
# 		     }
# 		   }
# 		})
# 	}else{
# 		alert("分类名称不能为空!");
# 	}
# }
# var inqueryobj;
# function showLogGreyBox1(objs,visible,area){
# 	var user = '';
# 	var user_service ='';
# 	var login_area = '';
# 	var pprovince='0';
# 	var vprovince='14';
# 	var serverareaid='';
#
# 	if(user!=null&&user!=""){
# 		if(user_service==null||user_service==''){
# 			if((visible!=''&&visible!=null&&visible!='0')||(pprovince=='33'&&pprovince=='33')){
# 				openWindow(objs);
# 			}else{
# 				alert("请购买服务后再收藏!");
# 			}
# 		}else{
# 			if(user_service.indexOf('CP022')>-1){
# 				if((visible!=''&&visible!=null&&visible!='0')||(serverareaid==''||serverareaid==null||serverareaid=='0')||(serverareaid.indexOf(area)>-1)){
# 					openWindow(objs);
# 				}else{
# 					alert("请购买服务后再收藏!");
# 				}
# 			}else{
# 				if((visible!=''&&visible!=null&&visible!='0')||(login_area=='33'&&area=='33')){
# 					openWindow(objs);
# 				}else{
# 					alert("请购买服务后再收藏!");
# 				}
# 			}
# 		}
# 	}else{
# 		alert("请登陆后再收藏!");
# 	}
# }
# function openWindow(objs){
# 	document.getElementById("sub1").disabled="";
# 	document.getElementById("newClass").disabled="";
# 	$("#class_id option").eq(0).attr('selected', 'true');
# 	inqueryobj = objs;
# 	var obj = document.getElementById("grey_box_div1");
# 	var W = screen.width;//取得屏幕分辨率宽度
# 	//var H = screen.height;//取得屏幕分辨率高度
# 	var yScroll;//取滚动条高度
# 	if (self.pageYOffset) {
# 		yScroll = self.pageYOffset;
# 	} else if (document.documentElement && document.documentElement.scrollTop){
# 		yScroll = document.documentElement.scrollTop;
# 	} else if (document.body) {
# 		yScroll = document.body.scrollTop;
# 	}
# 	yScroll = $(document).scrollTop();
# 	var cityOffset = $(objs).offset();
#
# 	var left = ($(window).width()-370)/2;
# 	//cityOffset.top元素，window.screen.height屏幕高度 ，260弹出层高度
# 	var top;
#
# 		if(yScroll>0){
#
# 			top = yScroll+(window.screen.height-260-110)/2;
# 		}else{
# 			top = (window.screen.height-260-110)/2;
# 		}
#
# 	obj.style.top = (top) + "px";
# 	obj.style.left = (left) + "px";
# 	obj.style.display="block";
# }
# function closeLogGreyBox1(){
# 	//关闭弹出层
# 	document.getElementById("grey_box_div1").style.display="none";
# 	$('#createclass').hide();
# 	$("#confirmbutton").show();
# 	var scrollstyle = scrolls1();
# 	scrollstyle.style.overflowY = "auto";
# 	scrollstyle.style.overflowX = "hidden";
# }
#
#
# function scrolls1(){
# 	//取浏览器类型
# 	var temp_h1 = document.body.clientHeight;
# 	var temp_h2 = document.documentElement.clientHeight;
# 	var isXhtml = (temp_h2<=temp_h1&&temp_h2!=0)?true:false;
# 	var htmlbody = isXhtml?document.documentElement:document.body;
# 	return htmlbody;
# }
#  function getAccessory_list(supply_id,accessory_id,fd_user_id){
#  	if(fd_user_id){
#
#  		window.open ("/mprice.do?method=getAccessoryList&supply_id="+supply_id+"&accessory_id="+accessory_id+"&fd_user_id="+fd_user_id,'newwindow','height=500,width=900,top=100,left=220,toolbar=no,menubar=no,scrollbars=no, resizable=no,location=no, status=no');
#  	}else{
#  		showLogGreyBox();
#  	}
#
#  }
#
#
#
# </script>
#
#
# 	<!-- IE6-8 不支持HTML5的浏览器支持HTML5的标签 -->
# 	<!--[if lt IE 9]>
#       <script src="http://v2.bootcss.com/assets/js/html5shiv.js"></script>
#     <![endif]-->
#
#
# 	<!--[if lte IE 6]>
# 	<link rel="stylesheet" type="text/css" href="/css/Kill-IE6-gh-pages/style-ie6.min.css" />
#     <script type="text/javascript" src="/css/Kill-IE6-gh-pages/script-ie6.min.js"></script>
# 	<![endif]-->
#
#
# 	<script type="text/javascript" src="/js/front/area_3.js"></script>
#
#
# 	<script type="text/javascript" src="/js/front/types.js"></script>
#
#
# 	<script type="text/javascript" src="/js/sea-modules/seajs/seajs/2.2.1/sea.js" id="seajsid"></script>
# 	<script type="text/javascript" src="/js/sea-modules/seajs/seajs-style/1.0.2/seajs-style.js" id="seajsstyleid"></script>
# 	<script>
# 	seajs.config({
# 		 base: "/js/sea-modules/",
# 		 alias: {
# 		      "jquery": "jquery/jquery/1.10.1/jquery.js",
# 		      "bootstrap":"ikj/bootstrap/2.3.2/bootstrap.js",
# 		      "cookie":"arale/cookie/1.0.2/cookie.js",
# 		      "base64":"seedit/base64/1.0.0/base64.js",
# 		      "qqService":"webapp/public/qq/qqService/0.0.1/qqService.js",
# 		      "manhuatoTop":"webapp/public/returnTop/manhuatoTop/0.0.1/manhuatoTop.js"
# 		    }
#
# 	});
#
#       var url="";
# 	  if (location.href.indexOf("jc/")>0) {
# 	     url="../js/net/price/market/src/main.js";
# 	  } else {
# 		 url="webapp/net/price/market/0.0.3/main";
# 	  }
# 	  seajs.use(url,function(mlist_new){
# 		    mlist_new.init();
# 	        mlist_new.accessory();
# 	    	mlist_new.qq('0', '0');
# 			mlist_new.manhuatoTop();
# 			mlist_new.smartFloat('yjs');
# 			mlist_new.recentlyViewed('countkeyword', '0', '0');
# 			mlist_new.BigdataCountAvg('','','46e589e257e288ef382dba98a02ffcac');
# 		});
#
#
#
# 	</script>
#
# </body>
# </html>
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# Ф6/HRB400
# Ф8-10/HRB400
# Ф6/HRB400E
# Ф8-10/HRB400
# Ф8-10/HPB300
# Ф6/HRB400
# Ф8-10/HPB300
# Ф8-10/HPB300
# Ф8-10/HRB400E
# Ф8-10/HPB300
# Ф8-10/HRB400
# Ф8-10/HRB400
# Ф8-10/HPB300
# Ф8-10/HRB400E
# Ф8-10/HRB400
# Ф8-10/HRB400
# Ф6/HRB400
# Ф8-10/HRB400
# Ф8/HRB400
# Ф8-10/HRB400
#
#
#
#
# Ф6/HRB400
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф6/HRB400E
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф8-10/HPB300
#
#
#
#
# Ф6/HRB400
#
#
#
#
# Ф8-10/HPB300
#
#
#
#
# Ф8-10/HPB300
#
#
#
#
# Ф8-10/HRB400E
#
#
#
#
# Ф8-10/HPB300
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф8-10/HPB300
#
#
#
#
# Ф8-10/HRB400E
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф6/HRB400
#
#
#
#
# Ф8-10/HRB400
#
#
#
#
# Ф8/HRB400
#
#
#
#
# Ф8-10/HRB400
