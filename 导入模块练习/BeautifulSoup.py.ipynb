# %%
import requests
url='http://ppt.ooopic.com/search------ooo-1.html?keyword=huandengpian&tid=20170712162610&cp=ppt&dy=quanguo&jh=liuliang&cx=huandengpian2&qd=baidu&sb=pc'
res=requests.get(url,verify=False)
res.encoding=res.apparent_encoding
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=gbk"/>
#     <link href="http://js.wotucdn.com/2017/ppt/bitbug_favicon.ico" rel="shortcut icon">
#     <title>PPT模板_PPT模板大全-第1页-我图网</title>
#     <meta name="keywords" content="PPT模板,PPT模板大全" />
#     <meta name="description" content="我图网页提供各种流行精品PPT课件模板,下载PPT模板就上我图网。" />
#     <link rel="stylesheet" type="text/css" href="//js.wotucdn.com/2017/ppt/common/css/ppt-style-base.v2.css?v=1025"/>
#     <link rel="stylesheet" type="text/css" href="//js.wotucdn.com/2017/ppt/so/css/ppt-so.v2.css?v=1025">
#     <script type="text/javascript">
#         var now=new Date();
#         var beginTime=now.getTime();
#         var obj={};
#         obj.picid       = 0;
#         obj.exeCode     = 6153;
#         obj.exeTime     = 0;
#         obj.loadCode        = 6154;
#         obj.loadTime        = 0;
#         obj.kid         = 0;
#         obj.bigclassid      = 0;
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(res.text,'lxml')

# %%
info=soup.select('.work-name')
print(info)
# Out:
# [<a class="work-name" href="http://ppt.ooopic.com/pic_26933963.html">2018年终工作总结新年计划动态PPT</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26932455.html">2018年泼墨风工作总结汇报PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26937051.html">2018大气简约工作总结</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26927905.html">2019粉色清晰教育培训PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26965310.html">2018全国两会政府工作报告ppt</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26963993.html">政府工作报告PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26922568.html">2019橙黑色商业计划书PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26939333.html">清新淡雅师说课教育教学公开课PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26964098.html">2018微立体简约新年工作汇报PPT模板</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26934951.html">立体大气总结商务汇报震撼工作计划PPT</a>, <a class="work-name" href="http://ppt.ooopic.com/pic_26964962.html">2018简约消费者权益日PPT模板</
# ...
